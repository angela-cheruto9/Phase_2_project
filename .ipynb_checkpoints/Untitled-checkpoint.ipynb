# %% [markdown]
# # DATA PREPARATION

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# load the dataset
df = pd.read_csv("kc_house_data.csv")
df.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
# 5    101930     1.0         0.0   0.0  ...     11        3890         1530.0
# 6      6819     2.0         0.0   0.0  ...      7        1715              ?
# 7      9711     1.0         0.0   NaN  ...      7        1060            0.0
# 8      7470     1.0         0.0   0.0  ...      7        1050          730.0
# 9      6560     2.0         0.0   0.0  ...      7        1890            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
# 5     2001           0.0    98053  47.6561 -122.005           4760      101930
# 6     1995           0.0    98003  47.3097 -122.327           2238        6819
# 7     1963           0.0    98198  47.4095 -122.315           1650        9711
# 8     1960           0.0    98146  47.5123 -122.337           1780        8113
# 9     2003           0.0    98038  47.3684 -122.031           2390        7570
#
# [10 rows x 21 columns]

# %%
# Observations 

# This dataset contains both continuous and categorical data
# It contains several time based columns like yr_built and yr_renovated
# It contains categorical data like the grade, condition

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Data Cleaning

# %%
# check the number of rows and columnns 
df.shape
# Out:
# (21597, 21)

# %%
# checkin the datatypes in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
# checking for unique data in the dataset
df.nunique()
# Out:
# id               21420
# date               372
# price             3622
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      304
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# dtype: int64

# %%
# checking why sqft_basement is an object
df.sqft_basement.unique()
# Out:
# array(['0.0', '400.0', '910.0', '1530.0', '?', '730.0', '1700.0', '300.0',
#        '970.0', '760.0', '720.0', '700.0', '820.0', '780.0', '790.0',
#        '330.0', '1620.0', '360.0', '588.0', '1510.0', '410.0', '990.0',
#        '600.0', '560.0', '550.0', '1000.0', '1600.0', '500.0', '1040.0',
#        '880.0', '1010.0', '240.0', '265.0', '290.0', '800.0', '540.0',
#        '710.0', '840.0', '380.0', '770.0', '480.0', '570.0', '1490.0',
#        '620.0', '1250.0', '1270.0', '120.0', '650.0', '180.0', '1130.0',
#        '450.0', '1640.0', '1460.0', '1020.0', '1030.0', '750.0', '640.0',
#        '1070.0', '490.0', '1310.0', '630.0', '2000.0', '390.0', '430.0',
#        '850.0', '210.0', '1430.0', '1950.0', '440.0', '220.0', '1160.0',
#        '860.0', '580.0', '2060.0', '1820.0', '1180.0', '200.0', '1150.0',
#        '1200.0', '680.0', '530.0', '1450.0', '1170.0', '1080.0', '960.0',
#        '280.0', '870.0', '1100.0', '460.0', '1400.0', '660.0', '1220.0',
#        '900.0', '420.0', '1580.0', '1380.0', '475.0', '690.0', '270.0',
#        '350.0', '935.0', '1370.0', '980.0', '1470.0', '160.0', '950.0',
#        '50.0', '740.0', '1780.0', '1900.0', '340.0', '470.0', '370.0',
#        '140.0', '1760.0', '130.0', '520.0', '890.0', '1110.0', '150.0',
#        '1720.0', '810.0', '190.0', '1290.0', '670.0', '1800.0', '1120.0',
#        '1810.0', '60.0', '1050.0', '940.0', '310.0', '930.0', '1390.0',
#        '610.0', '1830.0', '1300.0', '510.0', '1330.0', '1590.0', '920.0',
#        '1320.0', '1420.0', '1240.0', '1960.0', '1560.0', '2020.0',
#        '1190.0', '2110.0', '1280.0', '250.0', '2390.0', '1230.0', '170.0',
#        '830.0', '1260.0', '1410.0', '1340.0', '590.0', '1500.0', '1140.0',
#        '260.0', '100.0', '320.0', '1480.0', '1060.0', '1284.0', '1670.0',
#        '1350.0', '2570.0', '1090.0', '110.0', '2500.0', '90.0', '1940.0',
#        '1550.0', '2350.0', '2490.0', '1481.0', '1360.0', '1135.0',
#        '1520.0', '1850.0', '1660.0', '2130.0', '2600.0', '1690.0',
#        '243.0', '1210.0', '1024.0', '1798.0', '1610.0', '1440.0',
#        '1570.0', '1650.0', '704.0', '1910.0', '1630.0', '2360.0',
#        '1852.0', '2090.0', '2400.0', '1790.0', '2150.0', '230.0', '70.0',
#        '1680.0', '2100.0', '3000.0', '1870.0', '1710.0', '2030.0',
#        '875.0', '1540.0', '2850.0', '2170.0', '506.0', '906.0', '145.0',
#        '2040.0', '784.0', '1750.0', '374.0', '518.0', '2720.0', '2730.0',
#        '1840.0', '3480.0', '2160.0', '1920.0', '2330.0', '1860.0',
#        '2050.0', '4820.0', '1913.0', '80.0', '2010.0', '3260.0', '2200.0',
#        '415.0', '1730.0', '652.0', '2196.0', '1930.0', '515.0', '40.0',
#        '2080.0', '2580.0', '1548.0', '1740.0', '235.0', '861.0', '1890.0',
#        '2220.0', '792.0', '2070.0', '4130.0', '2250.0', '2240.0',
#        '1990.0', '768.0', '2550.0', '435.0', '1008.0', '2300.0', '2610.0',
#        '666.0', '3500.0', '172.0', '1816.0', '2190.0', '1245.0', '1525.0',
#        '1880.0', '862.0', '946.0', '1281.0', '414.0', '2180.0', '276.0',
#        '1248.0', '602.0', '516.0', '176.0', '225.0', '1275.0', '266.0',
#        '283.0', '65.0', '2310.0', '10.0', '1770.0', '2120.0', '295.0',
#        '207.0', '915.0', '556.0', '417.0', '143.0', '508.0', '2810.0',
#        '20.0', '274.0', '248.0'], dtype=object)

# %%
# dropping the rows that have '?'
df = df[df.sqft_basement != '?']

# %%
# converting the sqft_basement column from str to float
df['sqft_basement'] = df['sqft_basement'].astype('float')

# %%
# displaying values in float 
pd.set_option('display.float_format', lambda X: '%.5f'% X)

# %%
# check the statistic summary of the dataset
df.describe()
# Out:
#                     id         price    bedrooms   bathrooms  sqft_living  \
# count      21143.00000   21143.00000 21143.00000 21143.00000  21143.00000
# mean  4581004249.84827  540510.72743     3.37256     2.11608   2080.92073
# std   2876328198.00068  368075.06437     0.92492     0.76853    918.54756
# min      1000102.00000   78000.00000     1.00000     0.50000    370.00000
# 25%   2123049307.00000  322000.00000     3.00000     1.75000   1430.00000
# 50%   3904940140.00000  450000.00000     3.00000     2.25000   1910.00000
# 75%   7309100170.00000  645000.00000     4.00000     2.50000   2550.00000
# max   9900000190.00000 7700000.00000    33.00000     8.00000  13540.00000
#
#            sqft_lot      floors  waterfront        view   condition  \
# count   21143.00000 21143.00000 18804.00000 21082.00000 21143.00000
# mean    15087.13782     1.49359     0.00755     0.23333     3.40992
# std     41209.20008     0.53925     0.08657     0.76507     0.65050
# min       520.00000     1.00000     0.00000     0.00000     1.00000
# 25%      5043.00000     1.00000     0.00000     0.00000     3.00000
# 50%      7620.00000     1.50000     0.00000     0.00000     3.00000
# 75%     10695.50000     2.00000     0.00000     0.00000     4.00000
# max   1651359.00000     3.50000     1.00000     4.00000     5.00000
#
#             grade  sqft_above  sqft_basement    yr_built  yr_renovated  \
# count 21143.00000 21143.00000    21143.00000 21143.00000   17389.00000
# mean      7.65828  1789.06901      291.85172  1971.02322      82.99195
# std       1.17425   828.40977      442.49834    29.32194     398.48182
# min       3.00000   370.00000        0.00000  1900.00000       0.00000
# 25%       7.00000  1200.00000        0.00000  1952.00000       0.00000
# 50%       7.00000  1560.00000        0.00000  1975.00000       0.00000
# 75%       8.00000  2210.00000      560.00000  1997.00000       0.00000
# max      13.00000  9410.00000     4820.00000  2015.00000    2015.00000
#
#           zipcode         lat        long  sqft_living15   sqft_lot15
# count 21143.00000 21143.00000 21143.00000    21143.00000  21143.00000
# mean  98077.86889    47.56027  -122.21388     1987.27139  12738.94197
# std      53.53576     0.13859     0.14060      685.67034  27169.27366
# min   98001.00000    47.15590  -122.51900      399.00000    651.00000
# 25%   98033.00000    47.47125  -122.32800     1490.00000   5100.00000
# 50%   98065.00000    47.57200  -122.23000     1840.00000   7626.00000
# 75%   98117.00000    47.67820  -122.12500     2360.00000  10087.00000
# max   98199.00000    47.77760  -121.31500     6210.00000 871200.00000

# %%
# descriptive statistics of the dataset
df.describe().transpose()
# Out:
#                     count             mean              std           min  \
df.isnull().sum(axis=1).sort_values(ascending =False)
# Out:
# 7269     3
# 13863    3
# 8816     2
# 8539     2
# 1466     2
#         ..
# 8338     0
# 8341     0
# 8342     0
# 8343     0
# 21596    0
# Length: 21143, dtype: int64

# %%
# checking for percentage of null values in each row 
df.isnull().sum(axis=1).sort_values(ascending =False)/len(df)*100
# Out:
# 7269    0.01419
# 13863   0.01419
# 8816    0.00946
# 8539    0.00946
# 1466    0.00946
#           ...
# 8338    0.00000
# 8341    0.00000
# 8342    0.00000
# 8343    0.00000
# 21596   0.00000
# Length: 21143, dtype: float64

# %%
'''
Dropping the rows with missing values would result in losing a huge part of the data we are working on, so that might not be the best option
'''
# Out:
# '\nDropping the rows with missing values would result in losing a huge part of the data we are working on, so that might not be the best option\n'

# %% [markdown]
# # Working on the columns with null values

# %%
# checking statistic summary of the data in the view column 
df.view.describe()
# Out:
# count   21082.00000
# mean        0.23333
# std         0.76507
# min         0.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max         4.00000
# Name: view, dtype: float64

# %%
# replacing the null values in the view column with the median 
df.view = df.view.fillna( value = df.view.median())

# %%
# checking statistic summary of the data in the waterfront column 
df.waterfront.describe()
# Out:
# count   18804.00000
# mean        0.00755
# std         0.08657
# min         0.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max         1.00000
# Name: waterfront, dtype: float64

# %%
# checking the value_count of properties with a waterfront
df.waterfront.value_counts()
# Out:
# 0.00000    18662
# 1.00000      142
# Name: waterfront, dtype: int64

# %%
# replacing the null values in the waterfront column with the median 
df.waterfront = df.waterfront.fillna( value = df.waterfront.median())

# %%
# checking statistic summary of the data in the yr_renovated column 
df.yr_renovated.describe()
# Out:
# count   17389.00000
# mean       82.99195
# std       398.48182
# min         0.00000
# 25%         0.00000
# 50%         0.00000
# 75%         0.00000
# max      2015.00000
# Name: yr_renovated, dtype: float64

# %%
# replacing the null values in the waterfront column with the median 
df.yr_renovated = df.yr_renovated.fillna( value = df.yr_renovated.median())

# %%
# recheck if there are any missing values 
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# drop unnecessary columns
df.drop(['id','zipcode'], axis=1, inplace=True)

# %%
# inspecting the null values using a heatmap
sns.heatmap(df.isnull(),yticklabels = False ,cbar= False,cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
'''
The heatmap shows the absence of null values in the dataset
'''
# Out:
# '\nThe heatmap shows the absence of null values in the dataset\n'

# %% [markdown]
# # Correlation of features

# %%
# correlation of features
corr = df.corr()
corr
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot   floors  \
# price         1.00000   0.30920    0.52589      0.70233   0.08794  0.25635
# bedrooms      0.30920   1.00000    0.51384      0.57800   0.03226  0.17904
# bathrooms     0.52589   0.51384    1.00000      0.75528   0.08788  0.50407
# sqft_living   0.70233   0.57800    0.75528      1.00000   0.17294  0.35469
# sqft_lot      0.08794   0.03226    0.08788      0.17294   1.00000 -0.00752
# floors        0.25635   0.17904    0.50407      0.35469  -0.00752  1.00000
# waterfront    0.26597   0.00006    0.06463      0.10604   0.02121  0.02031
# view          0.39488   0.08021    0.18680      0.28295   0.07242  0.02773
# condition     0.03529   0.02571   -0.12802     -0.06129  -0.00967 -0.26428
# grade         0.66774   0.35688    0.66649      0.76310   0.11340  0.45921
# bedrooms             0.39248     0.03048
# bathrooms            0.57013     0.08883
# sqft_living          0.75639     0.18447
# sqft_lot             0.14343     0.72065
# floors               0.28029    -0.01154
# waterfront           0.08517     0.03025
# view                 0.28028     0.07255
# condition           -0.09349    -0.00486
# grade                0.71357     0.12192
# sqft_above           0.73102     0.19564
# sqft_basement        0.20158     0.01666
# yr_built             0.32545     0.07141
# yr_renovated         0.00129     0.00271
# lat                  0.05044    -0.08498
# long                 0.33427     0.25556
# sqft_living15        1.00000     0.18309
# sqft_lot15           0.18309     1.00000

# %%
# change correlation to True for positive or negative correlations that are bigger than 0.75 in the correlation matrix
abs(df.corr()) > 0.75
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price           True     False      False        False     False   False
# bedrooms       False      True      False        False     False   False
# bathrooms      False     False       True         True     False   False
# sqft_living    False     False       True         True     False   False
# sqft_lot       False     False      False        False      True   False
# floors         False     False      False        False     False    True
# waterfront     False     False      False        False     False   False
# view           False     False      False        False     False   False
# condition      False     False      False        False     False   False
# grade          False     False      False         True     False   False
# sqft_above     False     False      False         True     False   False
# sqft_basement  False     False      False        False     False   False
# yr_built       False     False      False        False     False   False
# yr_renovated   False     False      False        False     False   False
# lat            False     False      False        False     False   False
# long           False     False      False        False     False   False
# sqft_living15  False     False      False         True     False   False
# sqft_lot15     False     False      False        False     False   False
#
#                waterfront   view  condition  grade  sqft_above  sqft_basement  \
# price               False  False      False  False       False          False
# bedrooms            False  False      False  False       False          False
# bathrooms           False  False      False  False       False          False
# sqft_living         False  False      False   True        True          False
# sqft_lot            False  False      False  False       False          False
# floors              False  False      False  False       False          False
# waterfront           True  False      False  False       False          False
# view                False   True      False  False       False          False
# condition           False  False       True  False       False          False
# grade               False  False      False   True        True          False
# sqft_above          False  False      False   True        True          False
# sqft_basement       False  False      False  False       False           True
# yr_built            False  False      False  False       False          False
# yr_renovated        False  False      False  False       False          False
# lat                 False  False      False  False       False          False
# long                False  False      False  False       False          False
# sqft_living15       False  False      False  False       False          False
# sqft_lot15          False  False      False  False       False          False
#
#                yr_built  yr_renovated    lat   long  sqft_living15  sqft_lot15
# price             False         False  False  False          False       False
# bedrooms          False         False  False  False          False       False
# bathrooms         False         False  False  False          False       False
# sqft_living       False         False  False  False           True       False
# sqft_lot          False         False  False  False          False       False
# floors            False         False  False  False          False       False
# waterfront        False         False  False  False          False       False
# view              False         False  False  False          False       False
# condition         False         False  False  False          False       False
# grade             False         False  False  False          False       False
# sqft_above        False         False  False  False          False       False
# sqft_basement     False         False  False  False          False       False
# yr_built           True         False  False  False          False       False
# yr_renovated      False          True  False  False          False       False
# lat               False         False   True  False          False       False
# long              False         False  False   True          False       False
# sqft_living15     False         False  False  False           True       False
# sqft_lot15        False         False  False  False          False        True

# %%
# heatmap to show correlation of features
plt.figure(figsize =(15,15))
sns.heatmap(corr,cbar=True,square= True ,fmt = '.1f', annot=True,annot_kws={'size':10},cmap= 'viridis')
# Out:
# <AxesSubplot:>

# %%
'''
Most features in the dataset have a positive correlation with price as it is the target variable
'''
# Out:
# '\nMost features in the dataset have a positive correlation with price as it is the target variable\n'

# %% [markdown]
# # VISUALIZATION

# %%
# Histogram to represent the variables in the dataset 

df.hist(figsize=(15,15), bins='auto');

# %%
# Observations 

# price, sqft_living,sqft_above,sqft_living which are continuous variables and seem to be normally distributed.
# Most houses have one floor, 3 bedrooms, 2 bathrooms, and a condition of 3
# The number of houses built seems to increase over time with the 2000's having the most number of houses built.

# %% [markdown]
# # Sorting data

# %%
# sorting values of price in descending order to check the first 10 rows
df.sort_values(('price'), ascending =False).head(10)
# Out:
#             date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7245  10/13/2014 7700000.00000         6    8.00000        12050     27600
# 3910   6/11/2014 7060000.00000         5    4.50000        10040     37325
# 9245   9/19/2014 6890000.00000         6    7.75000         9890     31374
# 4407    8/4/2014 5570000.00000         5    5.75000         9200     35069
# 1446   4/13/2015 5350000.00000         5    5.00000         8000     23985
# 1313   4/13/2015 5300000.00000         6    6.00000         7390     24829
# 1162  10/20/2014 5110000.00000         5    5.25000         8010     45517
# 8085   6/17/2014 4670000.00000         5    6.75000         9640     13068
# 2624   8/15/2014 4500000.00000         5    5.50000         6640     40014
# 8629   6/18/2014 4490000.00000         4    3.00000         6430     27517
#
#       floors  waterfront    view  condition  grade  sqft_above  sqft_basement  \
# 7245 2.50000     0.00000 3.00000          4     13        8570     3480.00000
# 3910 2.00000     1.00000 2.00000          3     11        7680     2360.00000
# 9245 2.00000     0.00000 4.00000          3     13        8860     1030.00000
# 4407 2.00000     0.00000 0.00000          3     13        6200     3000.00000
# 1446 2.00000     0.00000 4.00000          3     12        6720     1280.00000
# 1313 2.00000     1.00000 0.00000          4     12        5000     2390.00000
# 1162 2.00000     1.00000 4.00000          3     12        5990     2020.00000
# 8085 1.00000     1.00000 4.00000          3     12        4820     4820.00000
# 2624 2.00000     1.00000 4.00000          3     12        6350      290.00000
# 8629 2.00000     0.00000 0.00000          3     12        6430        0.00000
#
#       yr_built  yr_renovated      lat       long  sqft_living15  sqft_lot15
# 7245      1910    1987.00000 47.62980 -122.32300           3940        8800
# 3910      1940    2001.00000 47.65000 -122.21400           3930       25449
# 9245      2001       0.00000 47.63050 -122.24000           4540       42730
# 4407      2001       0.00000 47.62890 -122.23300           3560       24345
# 1446      2009       0.00000 47.62320 -122.22000           4600       21750
# 1313      1991       0.00000 47.56310 -122.21000           4320       24619
# 1162      1999       0.00000 47.67670 -122.21100           3430       26788
# 8085      1983    2009.00000 47.55700 -122.21000           3270       10454
# 2624      2004       0.00000 47.74930 -122.28000           3030       23408
# 8629      2001       0.00000 47.62080 -122.21900           3720       14592

# %%
'''
The most expensive properties occuppy a huge sqft_above the ground,high grade and have an above average number of bathrooms

'''
# Out:
# '\nThe most expensive properties occuppy a huge sqft_above the ground,high grade and have an above average number of bathrooms\n\n'

# %%
# sorting values of price in descending order to check the last 10 rows
df.sort_values(('price'), ascending =False).tail(10)
# Out:
#             date       price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 13743  7/22/2014 86500.00000         3    1.00000          840      9480
# 16700   3/5/2015 85000.00000         2    1.00000          910      9753
# 10242  9/15/2014 85000.00000         2    1.00000          830      9000
# 3763   4/30/2015 84000.00000         2    1.00000          700     20130
# 18453  5/29/2014 83000.00000         2    1.00000          900      8580
# 2139    5/8/2014 82500.00000         2    1.00000          520     22334
# 8267   11/5/2014 82000.00000         3    1.00000          860     10426
# 16184  3/24/2015 81000.00000         2    1.00000          730      9975
# 465    5/23/2014 80000.00000         1    0.75000          430      5050
# 15279   5/6/2014 78000.00000         2    1.00000          780     16344
#
#        floors  waterfront    view  condition  grade  sqft_above  \
# 13743 1.00000     0.00000 0.00000          3      6         840
# 16700 1.00000     0.00000 0.00000          3      5         910
# 10242 1.00000     0.00000 0.00000          3      6         830
# 3763  1.00000     0.00000 0.00000          3      6         700
# 18453 1.00000     0.00000 0.00000          3      5         900
# 2139  1.00000     0.00000 0.00000          2      5         520
# 8267  1.00000     0.00000 0.00000          3      6         860
# 16184 1.00000     0.00000 0.00000          1      5         730
# 465   1.00000     0.00000 0.00000          2      4         430
# 15279 1.00000     0.00000 0.00000          1      5         780
#
#        sqft_basement  yr_built  yr_renovated      lat       long  \
# 13743        0.00000      1960       0.00000 47.32770 -122.34100
# 16700        0.00000      1947       0.00000 47.38970 -122.23600
# 10242        0.00000      1939       0.00000 47.38130 -122.24300
# 3763         0.00000      1949       0.00000 47.47520 -122.27100
# 18453        0.00000      1918       0.00000 47.47270 -122.27000
# 2139         0.00000      1951       0.00000 47.47990 -122.29600
# 8267         0.00000      1954       0.00000 47.49870 -122.34100
# 16184        0.00000      1943       0.00000 47.48080 -122.31500
# 465          0.00000      1912       0.00000 47.64990 -121.90900
# 15279        0.00000      1942       0.00000 47.47390 -122.28000
#
#        sqft_living15  sqft_lot15
# 13743            840        9420
# 16700           1160        7405
# 10242           1160        7680
# 3763            1490       18630
# 18453           2060        6533
# 2139            1572       10570
# 8267            1140       11250
# 16184            860        9000
# 465             1200        7500
# 15279           1700       10387

# %%
'''
The least expensive houses occupy a smaller sqft_above ground,have a lower than average bathrooms and mostly have one floor

'''
# Out:
# '\nThe least expensive houses occupy a smaller sqft_above ground,have a lower than average bathrooms and mostly have one floor\n\n'

# %%
# checking the value_count of price of the houses in the dataset
df['price'].value_counts()
# Out:
# 350000.00000    168
# 450000.00000    167
# 550000.00000    155
# 500000.00000    149
# 425000.00000    146
#                ...
# 278800.00000      1
# 439888.00000      1
# 354901.00000      1
# 942000.00000      1
# 402101.00000      1
# Name: price, Length: 3581, dtype: int64

# %%
'''
Most houses are at a price of 450,000 and 350,000

'''
# Out:
# '\nMost houses are at a price of 450,000 and 350,000\n\n'

# %%
# checking the value_count for each variable in the dataset 
for value in df:
    print(df[value].value_counts())
    print()
# Out:
# 6/23/2014    139
# 6/25/2014    130
# 7/8/2014     126
# 6/26/2014    125
# 3/25/2015    122
#             ...
# 11/2/2014      1
# 1/31/2015      1
# 5/24/2015      1
# 5/17/2014      1
# 7/27/2014      1
# Name: date, Length: 372, dtype: int64
#
# 350000.00000    168
# 450000.00000    167
# 550000.00000    155
# 500000.00000    149
# 425000.00000    146
#                ...
# 278800.00000      1
# 439888.00000      1
# 354901.00000      1
# 942000.00000      1
# 402101.00000      1
# Name: price, Length: 3581, dtype: int64
#
# 3     9639
# 4     6740
# 2     2691
# 5     1560
# 6      262
# 1      191
# 7       36
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64
#
# 2.50000    5255
# 1.00000    3757
# 1.75000    2991
# 2.25000    2014
# 2.00000    1886
# 1.50000    1422
# 2.75000    1160
# 3.00000     736
# 3.50000     719
# 3.25000     574
# 3.75000     152
# 4.00000     135
# 4.50000      96
# 4.25000      79
# 0.75000      71
# 4.75000      23
# 5.00000      19
# 5.25000      13
# 1.25000       9
# 5.50000       9
# 6.00000       6
# 5.75000       4
# 0.50000       3
# 6.75000       2
# 8.00000       2
# 6.25000       2
# 6.50000       2
# 7.50000       1
# 7.75000       1
# Name: bathrooms, dtype: int64
#
# 1300    135
# 1400    134
# 1440    130
# 1010    127
# 1660    127
#        ...
# 5844      1
# 2507      1
# 9890      1
# 5584      1
# 1425      1
# Name: sqft_living, Length: 1025, dtype: int64
#
# 5000      348
# 6000      286
# 4000      244
# 7200      218
# 7500      119
#          ...
# 263538      1
# 22605       1
# 25248       1
# 9934        1
# 1076        1
# Name: sqft_lot, Length: 9643, dtype: int64
#
# 1.00000    10456
# 2.00000     8066
# 1.50000     1865
# 3.00000      593
# 2.50000      156
# 3.50000        7
# Name: floors, dtype: int64
#
# 0.00000    21001
# 1.00000      142
# Name: waterfront, dtype: int64
#
# 0.00000    19079
# 2.00000      930
# 3.00000      496
# 1.00000      327
# 4.00000      311
# Name: view, dtype: int64
#
# 3    13726
# 4     5557
# 5     1666
# 2      166
# 1       28
# Name: condition, dtype: int64
#
# 7     8788
# 8     5933
# 9     2557
# 6     1997
# 10    1112
# 11     391
# 5      235
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64
#
# 1300    208
# 1010    207
# 1200    199
# 1220    191
# 1140    182
#        ...
# 3674      1
# 2979      1
# 2382      1
# 6290      1
# 1425      1
# Name: sqft_above, Length: 935, dtype: int64
#
# 0.00000       12826
# 600.00000       217
# 500.00000       209
# 700.00000       208
# 800.00000       201
#               ...
# 1920.00000        1
# 3480.00000        1
# 2730.00000        1
# 2720.00000        1
# 248.00000         1
# Name: sqft_basement, Length: 303, dtype: int64
#
# 2014    542
# 2006    443
# 2005    435
# 2004    422
# 2003    416
#        ...
# 1933     30
# 1901     28
# 1902     27
# 1935     23
# 1934     21
# Name: yr_built, Length: 116, dtype: int64
#
# 0.00000       20420
# 2014.00000       69
# 2003.00000       31
# 2013.00000       31
# 2007.00000       30
#               ...
# 1959.00000        1
# 1951.00000        1
# 1976.00000        1
# 1953.00000        1
# 1948.00000        1
# Name: yr_renovated, Length: 69, dtype: int64
#
# 47.54910    17
# 47.66240    17
# 47.53220    17
# 47.69550    16
# 47.67110    16
#             ..
# 47.22210     1
# 47.40670     1
# 47.29730     1
# 47.43840     1
# 47.65020     1
# Name: lat, Length: 5018, dtype: int64
#
# -122.29000    113
# -122.30000    109
# -122.36200    104
# -122.36300     98
# -122.29100     98
#              ...
# -121.72400      1
# -121.69100      1
# -122.51400      1
# -121.64600      1
# -121.40300      1
# Name: long, Length: 750, dtype: int64
#
# 1440    194
# 1540    192
# 1560    188
# 1500    173
# 1460    165
#        ...
# 1302      1
# 1518      1
# 2112      1
# 4260      1
# 2927      1
# Name: sqft_living15, Length: 773, dtype: int64
#
# 5000     416
# 4000     349
# 6000     283
# 7200     209
# 4800     140
#         ...
# 11489      1
# 14484      1
# 1709       1
# 8721       1
# 2007       1
# Name: sqft_lot15, Length: 8572, dtype: int64

# %%
# displot to show the price distribution 

plt.figure(figsize = (20,18))
sns.displot(df['price'])

# %%
'''
The distplot is more skewed to the left meaning that the observations are either small or medium, with a few observations that are larger than the rest.
'''
# Out:
# '\nThe distplot is more skewed to the left meaning that the observations are either small or medium, with a few observations that are larger than the rest.\n'

# %%
# convert the date column so that pandas recognizes it as a date 
df['date'] = pd.to_datetime(df['date'])

# %%
# create a colum to hold the month data extracted from the date column,in order to find out if the seasons(summer,winter,spring,autumn)affect house prices
df['month'] = df['date'].dt.month

# %% [markdown]
# # Checking relationship of the data in the dataset

# %%
# scatterplot to show the distribution of waterfront against price

plt.figure(figsize = (10,6))
sns.scatterplot(x = 'month' , y ='price', data=df , hue ='waterfront')
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
# boxplot to show the distribution of waterfront against price

plt.figure(figsize = (10,6))
sns.boxplot(x='waterfront' , y ='price', data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
'''
Waterfront properties sold at a higher price as compared to houses without a waterfront.
The most expensive property being sold in June and the least expensive being sold in January
The seasons do not seem to affect the rate at which the houses were sold
'''
# Out:
# '\nWaterfront properties sold at a higher price as compared to houses without a waterfront.\nThe most expensive property being sold in June and the least expensive being sold in January\nThe seasons do not seem to affect the rate at which the houses were sold\n'

# %%
# scatterplot to show the distribution of waterfront against price

plt.figure(figsize = (10,6))
sns.scatterplot(x='long' , y ='lat', data=df , hue ='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
'''
Most areas closer to the water seem to have a higher price compared to the others
'''
# Out:
# '\nMost areas closer to the water seem to have a higher price compared to the others\n'

# %%
# scatterplot to show the distribution of waterfront against price

plt.figure(figsize = (10,6))
sns.scatterplot(x = 'month' , y ='price', data=df , hue ='view')
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
'''
The number of times a house is viewed and how much it sells seems to be even across the months, however we might say that the more the houses were viewed the more they are likely to sell
The most expensive house that had been viewed sold in October
The more a house is viewed seems to have an effect on price
'''
# Out:
# '\nThe number of times a house is viewed and how much it sells seems to be even across the months, however we might say that the more the houses were viewed the more they are likely to sell\nThe most expensive house that had been viewed sold in October\nThe more a house is viewed seems to have an effect on price\n'

# %%
# displot to show the distribution of bedrooms

plt.figure(figsize = (10,6))
sns.countplot(df['bedrooms'])
# Out:
# C:\Users\ADMIN\anaconda3\An4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
'''
Most houses sold have an average of 3 bedrooms

'''
# Out:
# '\nMost houses sold have an average of 3 bedrooms\n\n'

# %%
# boxplot to show the distribution of bedrooms against price

plt.figure(figsize = (10,6))
sns.boxplot(x='bedrooms' , y ='price', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
'''
There is presence of outliers,for example the houses with extraordinary number of rooms like the 10,11,33 bedrooms that are way above the bedroom average could be the reason for the high prices
'''
# Out:
# '\nThere is presence of outliers,for example the houses with extraordinary number of rooms like the 10,11,33 bedrooms that are way above the bedroom average could be the reason for the high prices\n'

# %%
# displot to show the distribution of bathrooms

plt.figure(figsize = (15,6))
sns.countplot(df['bathrooms'])
# Out:
# C:\Users\ADMIN\anaconda3\An4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms', ylabel='count'>

# %%
'''
Most houses have an average of 2.5 bathrooms 
'''
# Out:
# '\nMost houses have an average of 2.5 bathrooms \n'

# %%
# plot a boxplot to show the distribution of bathrooms against price

plt.figure(figsize = (15,6))
sns.boxplot(x='bathrooms' , y ='price', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
'''
The outliers could be due to the few houses with bathrooms way above or below average
'''
# Out:
# '\nThe outliers could be due to the few houses with bathrooms way above or below average\n'

# %%
# histogram to show grade distribution

data= df['grade']
plt.figure(figsize=(10,5))
plt.hist(data, bins=30, align='left', color='b', edgecolor='black',
              linewidth=1)
 
# axis labels
plt.xlabel("grade")
plt.xticks(rotation= 80,fontsize=10)
plt.ylabel("Frequency of grade")
plt.title("Distribution of grade in the dataset")
 
plt.show()

# %%
'''
Most houses have a grade of 7
'''
# Out:
# '\nMost houses have a grade of 7\n'

# %%
# boxplot to show the distribution of grade against price

plt.figure(figsize = (10,6))
sns.boxplot(x='grade' , y ='price', data=df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
# histogram to show the yr_built column distribution

# plot a histogram to show the distribution of yr_built
data= df['yr_built']
plt.figure(figsize=(10,5))
plt.hist(data, bins=30, align='left', color='b', edgecolor='black',
              linewidth=1)
 
# Add axis labels
plt.xlabel("yr_built")
plt.xticks(rotation= 80,fontsize=10)
plt.ylabel("Frequency of yr_built")
plt.title("Distribution of yr_built in the dataset")
 
plt.show()

# %%
'''
The number of houses built increases over the years
'''
# Out:
# '\nThe number of houses built increases over the years\n'

# %%
# displot to show the distribution of floors

plt.figure(figsize = (10,6))
sns.countplot(df['floors'])
# Out:
# C:\Users\ADMIN\anaconda3\An4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
'''
Most houses have one or two floors
'''
# Out:
# '\nMost houses have one or two floors\n'

# %%
# Scatter plot to show the correlation of the sqft_living against price
plt.figure(figsize = (10,6))
sns.scatterplot(x='sqft_living', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
'''
The correlation between sqft_living and price is a strong positive correlation, therefore the more the sqft_living space there is a significant increase in price
'''
# Out:
# '\nThe correlation between sqft_living and price is a strong positive correlation, therefore the more the sqft_living space there is a significant increase in price\n'

# %%
# Scatter plot to show the correlation of the sqft_lot against price
plt.figure(figsize = (10,6))
sns.scatterplot(x='sqft_lot', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %%
'''
The sqft_lot and price have a weak positive correlation, therefore an increase in sqft_lot space there is a small noticeable increase in price
'''
# Out:
# '\nThe sqft_lot and price have a weak positive correlation, therefore an increase in sqft_lot space there is a small noticeable increase in price\n'

# %%
# Scatter plot to show the correlation of condition against price
plt.figure(figsize = (10,6))
sns.scatterplot(x='condition', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
'''
Most houses seem to have a condition of 3 or 4
'''
# Out:
# '\nMost houses seem to have a condition of 3 or 4\n'

# %% [markdown]
# # Splitting data into categorical and numerical data

# %%
# dropping unnecessary columns
df.drop(['waterfront','condition'], axis=1, inplace=True)

# %%
# creating new variables to hold the categorical data

df_categorical =df[['view','month','yr_built','yr_renovated']]

# %%
# creating new variables to hold the numerical data
df_numerical = df[['price','bedrooms','bathrooms','floors','sqft_lot','sqft_basement','sqft_above','lat','long','sqft_living15','sqft_lot15']]

# %%
# create bins
bins = [0, 1, 4]
# split view column into viewed and unviewed houses
labels = ['unviewed','viewed']
bins_viewed = pd.cut(df['view'], bins=bins, include_lowest = True,labels=labels)
bins_viewed = bins_viewed.cat.as_unordered()

# %%
# value_count for viewed and unviewed houses
views = bins_viewed.value_counts()
views
# Out:
# unviewed    19406
# viewed       1737
# Name: view, dtype: int64

# %%
# bargraph to show the total viewed and unviewed houses
views.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# summary statistics of categorical variables
df_categorical.describe()
# Out:
#              view       month    yr_built  yr_renovated
# count 21143.00000 21143.00000 21143.00000   21143.00000
# mean      0.23265     6.57466  1971.02322      68.25649
# std       0.76406     3.11543    29.32194     362.76583
# min       0.00000     1.00000  1900.00000       0.00000
# 25%       0.00000     4.00000  1952.00000       0.00000
# 50%       0.00000     6.00000  1975.00000       0.00000
# 75%       0.00000     9.00000  1997.00000       0.00000
# max       4.00000    12.00000  2015.00000    2015.00000

# %%
# create bins to hold the column data
bins = [0, 1, 2015]
# split yr_renovated column to renovated and not_renovated houses
labels = ['not_renovated','renovated']
renovated_bins = pd.cut(df['yr_renovated'], bins=bins,include_lowest = True, labels=labels)
renovated_bins = renovated_bins.cat.as_unordered()

# %%
# value_count for renovated and not_renovated bins
renovated_bins.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# drop yr_renovated columns 
df_categorical = df_categorical.drop(columns=['view','yr_renovated'])

# replace the dropped columns with the binned data
df_categorical= pd.concat([df_categorical, bins_viewed,renovated_bins], axis=1)

# %%
# checking the categorical data
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         21143 non-null  int64
#  1   yr_built      21143 non-null  int64
#  2   view          21143 non-null  category
#  3   yr_renovated  21143 non-null  category
# dtypes: category(2), int64(2)
# memory usage: 1.0 MB

# %% [markdown]
# # one-hot encoding

# %%
# hot encoding data for prediction
df_categorical = pd.get_dummies(df_categorical) 
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   month                       21143 non-null  int64
#  1   yr_built                    21143 non-null  int64
#  2   view_unviewed               21143 non-null  uint8
#  3   view_viewed                 21143 non-null  uint8
#  4   yr_renovated_not_renovated  21143 non-null  uint8
#  5   yr_renovated_renovated      21143 non-null  uint8
# dtypes: int64(2), uint8(4)
# memory usage: 1.1 MB

# %%
# hot encoding the data once more
df_categorical = pd.get_dummies(df_categorical) 
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   month                       21143 non-null  int64
#  1   yr_built                    21143 non-null  int64
#  2   view_unviewed               21143 non-null  uint8
#  3   view_viewed                 21143 non-null  uint8
#  4   yr_renovated_not_renovated  21143 non-null  uint8
#  5   yr_renovated_renovated      21143 non-null  uint8
# dtypes: int64(2), uint8(4)
# memory usage: 1.1 MB

# %%
# inspecting the categorical data
df_categorical.head()
# Out:
#    month  yr_built  view_unviewed  view_viewed  yr_renovated_not_renovated  \
# 0     10      1955              1            0                           1
# 1     12      1951              1            0                           0
# 2      2      1933              1            0                           1
# 3     12      1965              1            0                           1
# 4      2      1987              1            0                           1
#
#    yr_renovated_renovated
# 0                       0
# 1                       1
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# # Standardization/ Normalization of numerical data

# %% [markdown]
# # mean normalization

# %%
# import standardscaler
from sklearn.preprocessing import StandardScaler
# referencing the standardscaler
std = StandardScaler()
std
# Out:
# StandardScaler()

# %%
# creating a variable for scaled data
# fitting and transforming data
df_std = pd.DataFrame(std.fit_transform(df_numerical),columns = df_numerical.columns) 
df_std.head()
# Out:
#      price  bedrooms  bathrooms   floors  sqft_lot  sqft_basement  sqft_above  \
# 0 -0.86563  -0.40281   -1.45226 -0.91535  -0.22901       -0.65957    -0.73524
# 1 -0.00682  -0.40281    0.17426  0.93912  -0.19038        0.24441     0.45984
# 2 -0.97947  -1.48402   -1.45226 -0.91535  -0.12345       -0.65957    -1.23018
# 3  0.17249   0.67839    1.15017 -0.91535  -0.24478        1.39698    -0.89217
# 4 -0.08289  -0.40281   -0.15104 -0.91535  -0.17004       -0.65957    -0.13166
#
#        lat     long  sqft_living15  sqft_lot15
# 0 -0.35410 -0.30673       -0.94402    -0.26092
# 1  1.15974 -0.74771       -0.43356    -0.18771
# 2  1.28168 -0.13602        1.06866    -0.17214
# 3 -0.28483 -1.27405       -0.91485    -0.28485
# 4  0.40787  1.20117       -0.27313    -0.19272

# %%
# summary statistics of numerical data
df_std.describe()
# Out:
#             price    bedrooms   bathrooms      floors    sqft_lot  \
# count 21143.00000 21143.00000 21143.00000 21143.00000 21143.00000
# mean      0.00000    -0.00000    -0.00000     0.00000     0.00000
# std       1.00002     1.00002     1.00002     1.00002     1.00002
# min      -1.25660    -2.56522    -2.10287    -0.91535    -0.35350
# 25%      -0.59367    -0.40281    -0.47635    -0.91535    -0.24374
# 50%      -0.24591    -0.40281     0.17426     0.01188    -0.18121
# 75%       0.28389     0.67839     0.49956     0.93912    -0.10657
# max      19.45163    32.03332     7.65625     3.72083    39.70741
#
#        sqft_basement  sqft_above         lat        long  sqft_living15  \
# count    21143.00000 21143.00000 21143.00000 21143.00000    21143.00000
# mean         0.00000     0.00000     0.00000    -0.00000        0.00000
# std          1.00002     1.00002     1.00002     1.00002        1.00002
# min         -0.65957    -1.71304    -2.91781    -2.17025       -2.31643
# 25%         -0.65957    -0.71110    -0.64237    -0.81173       -0.72525
# 50%         -0.65957    -0.27652     0.08461    -0.11468       -0.21479
# 75%          0.60600     0.50813     0.85091     0.63215        0.54361
# max         10.23338     9.19969     1.56814     6.39343        6.15869
#
#        sqft_lot15
# count 21143.00000
# mean      0.00000
# std       1.00002
# min      -0.44492
# 25%      -0.28117
# 50%      -0.18819
# 75%      -0.09761
# max      31.59751

# %%
# Histogram to represent all numerical data in the dataset 
df_std.hist(figsize = (15,10), color = "b", lw=0);

# %%
# Histogram to represent all numerical data in the dataset 

df_std.hist(figsize=(20,15), bins='auto');

# %%
'''
sqft_livng15, sqft_above, bathrooms and long seem to be somehow normally distributed compared to the other columns, however, they are positively skewed.
sqft_lot, sqft_basement, floors, sqft_lot15, and price all seem to be positively skewed as the graph tends to lean to the left
lat is the only plot that is negatively skewed
'''
# Out:
# '\nsqft_livng15, sqft_above, bathrooms and long seem to be somehow normally distributed compared to the other columns, however, they are positively skewed.\nsqft_lot, sqft_basement, floors, sqft_lot15, and price all seem to be positively skewed as the graph tends to lean to the left\nlat is the only plot that is negatively skewed\n'

# %% [markdown]
# # Min-max normalization

# %%
# import min-max scaler
from sklearn.preprocessing import MinMaxScaler 
# referencing the scaler
mmscaler = MinMaxScaler() 
df_minmax = pd.DataFrame(mmscaler.fit_transform(df_numerical),columns = df_numerical.columns)

# %%
# Histogram to represent all numerical data in the dataset 
df_minmax.hist(figsize = (15,10), color = "skyblue");

# %%
# Histogram to represent the variables in the dataset 

df_minmax.hist(figsize=(15,10), bins='auto');

# %%
'''
sqft_livng15, sqft_above, bathrooms ,long and price seem to be somehow normally distributed compared to the other columns, however, they are positively skewed.
sqft_lot, sqft_basement,sqft_lot15,sqft_abovelong,bedrooms and all seem to be positively skewed as the graph tends to lean to the left
lat is the only plot that is negatively skewed
'''
# Out:
# '\nsqft_livng15, sqft_above, bathrooms ,long and price seem to be somehow normally distributed compared to the other columns, however, they are positively skewed.\nsqft_lot, sqft_basement,sqft_lot15,sqft_abovelong,bedrooms and all seem to be positively skewed as the graph tends to lean to the left\nlat is the only plot that is negatively skewed\n'

# %% [markdown]
# # Log transformation to reduce skewness of data

# %%
import warnings
warnings.filterwarnings('ignore')

# create a dataframe to hold the data from df_numerical
df_price_log= pd.DataFrame([]) 
df_price_log = df_numerical

# %%
# price log transformation
df_price_log['price']= np.log(df_price_log['price'])

# mean normalization on the numerical/continuous data
df_price_log['bathrooms']= (df_price_log['bathrooms'] - df_price_log['bathrooms'].mean())/df_price_log['bathrooms'].std()
df_price_log['bedrooms']= (df_price_log['bedrooms'] - df_price_log['bedrooms'].mean())/df_price_log['bedrooms'].std()
df_price_log['floors']= (df_price_log['floors'] - df_price_log['floors'].mean())/df_price_log['floors'].std()
df_price_log['sqft_lot']= (df_price_log['sqft_lot'] - df_price_log['sqft_lot'].mean())/df_price_log['sqft_lot'].std()
df_price_log['sqft_above']= (df_price_log['sqft_above'] - df_price_log['sqft_above'].mean())/df_price_log['sqft_above'].std()
df_price_log['lat']= (df_price_log['lat'] - df_price_log['lat'].mean())/df_price_log['lat'].std()
df_price_log['long']= (df_price_log['long'] - df_price_log['long'].mean())/df_price_log['long'].std()
df_price_log['sqft_living15']= (df_price_log['sqft_living15'] - df_price_log['sqft_living15'].mean())/df_price_log['sqft_living15'].std()
df_price_log['sqft_lot15']= (df_price_log['sqft_lot15'] - df_price_log['sqft_lot15'].mean())/df_price_log['sqft_lot15'].std()

df_price_log.head()
# Out:
#      price  bedrooms  bathrooms   floors  sqft_lot  sqft_basement  sqft_above  \
# 0 12.30998  -0.40280   -1.45222 -0.91533  -0.22901        0.00000    -0.73523
# 1 13.19561  -0.40280    0.17426  0.93910  -0.19037      400.00000     0.45983
# 2 12.10071  -1.48398   -1.45222 -0.91533  -0.12345        0.00000    -1.23015
# 3 13.31133   0.67838    1.15014 -0.91533  -0.24478      910.00000    -0.89215
# 4 13.14217  -0.40280   -0.15104 -0.91533  -0.17004        0.00000    -0.13166
#
#        lat     long  sqft_living15  sqft_lot15
# 0 -0.35409 -0.30672       -0.94400    -0.26092
# 1  1.15971 -0.74770       -0.43355    -0.18771
# 2  1.28165 -0.13602        1.06863    -0.17214
# 3 -0.28483 -1.27402       -0.91483    -0.28484
# 4  0.40786  1.20114       -0.27312    -0.19272

# %%
# histogram showing price distribution
df_price_log['price'].hist()
# Out:
# <AxesSubplot:>

# %%
'''
We can now say that the price is normally distributed in the dataset after performing log transformation on our target variable(price)

'''
# Out:
# '\nWe can now say that the price is normally distributed in the dataset after performing log transformation on our target variable(price)\n\n'

# %% [markdown]
# # KDE  plots

# %%
# from our normalized data create a list of columns
data = list(df_price_log) 
# checking the list of columns using for loop
for column in data:
    # create a histogram
    df_price_log[column].plot.hist(density=True, label = column+' histogram' ) 
    # create a KDE plot
    df_price_log[column].plot.kde(label =column+' kde') 
    plt.legend()
    plt.show()

# %%
'''
The data seems to be a little bit more detailed as compared to the ones illustrated above using histograms.Latitude is still however negativel skewed

'''
# Out:
# '\nThe data seems to be a little bit more detailed as compared to the ones illustrated above using histograms.Latitude is still however negativel skewed\n\n'

# %% [markdown]
# # jointplots

# %%
# from the list of normalized data create a joint plot
import warnings
warnings.filterwarnings('ignore')

# access each column in the data
for column in data:
    # price is still our target variable
    sns.jointplot(x=column, y="price",data= df_price_log,kind='reg',label=column,joint_kws={'line_kws':{'color':'red'}})

    plt.legend() 
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
'''
Most of the variables are positively correlated with price with exception of some like latitude which has a very weak positive correlation with price. An increase in the variable results in an increase in price
House buyers seem to care about Sqft_above because it seems to have the highest slope and has a high positive correlation with price compared to others, which means a slight increase in sqft_above results in a significant increase in price, this was followed by sqft_living15
'''
# Out:
# '\nMost of the variables are positively correlated with price with exception of some like latitude which has a very weak positive correlation with price. An increase in the variable results in an increase in price\nHouse buyers seem to care about Sqft_above because it seems to have the highest slope and has a high positive correlation with price compared to others, which means a slight increase in sqft_above results in a significant increase in price, this was followed by sqft_living15\n'

# %%
# joining categorical data to numerical data
df_num_cat = pd.concat([df_price_log, df_categorical], axis=1) 
df_num_cat.head()
# Out:
#      price  bedrooms  bathrooms   floors  sqft_lot  sqft_basement  sqft_above  \
# 0 12.30998  -0.40280   -1.45222 -0.91533  -0.22901        0.00000    -0.73523
# 1 13.19561  -0.40280    0.17426  0.93910  -0.19037      400.00000     0.45983
# 2 12.10071  -1.48398   -1.45222 -0.91533  -0.12345        0.00000    -1.23015
# 3 13.31133   0.67838    1.15014 -0.91533  -0.24478      910.00000    -0.89215
# 4 13.14217  -0.40280   -0.15104 -0.91533  -0.17004        0.00000    -0.13166
#
#        lat     long  sqft_living15  sqft_lot15  month  yr_built  \
# 0 -0.35409 -0.30672       -0.94400    -0.26092     10      1955
# 1  1.15971 -0.74770       -0.43355    -0.18771     12      1951
# 2  1.28165 -0.13602        1.06863    -0.17214      2      1933
# 3 -0.28483 -1.27402       -0.91483    -0.28484     12      1965
# 4  0.40786  1.20114       -0.27312    -0.19272      2      1987
#
#    view_unviewed  view_viewed  yr_renovated_not_renovated  \
# 0              1            0                           1
# 1              1            0                           0
# 2              1            0                           1
# 3              1            0                           1
# 4              1            0                           1
#
#    yr_renovated_renovated
# 0                       0
# 1                       1
# 2                       0
# 3                       0
# 4                       0

# %%
# checking data types in the column
df_num_cat.dtypes
# Out:
# price                         float64
# bedrooms                      float64
# bathrooms                     float64
# floors                        float64
# sqft_lot                      float64
# sqft_basement                 float64
# sqft_above                    float64
# lat                           float64
# long                          float64
# sqft_living15                 float64
# sqft_lot15                    float64
# month                           int64
# yr_built                        int64
# view_unviewed                   uint8
# view_viewed                     uint8
# yr_renovated_not_renovated      uint8
# yr_renovated_renovated          uint8
# dtype: object

# %%
# converting categorical data to category
for categorical_names in df_num_cat.iloc[:,11:].columns:
         df_num_cat[categorical_names] = df_num_cat[categorical_names].astype('category')

# %% [markdown]
# # Modelling data

# %% [markdown]
# # OLS regression

# %%
# importing the required libraries

import statsmodels.api as sm #importing the necessary libraries
import statsmodels.formula.api as smf

# %%
# OLS model for numerical data

# %%
# estimate model
df = df_num_cat
f = 'price ~  bedrooms + bathrooms + floors + sqft_lot + sqft_basement +sqft_above + lat + long + sqft_living15 ' 
# fitting the model
model = smf.ols(formula=f, data=df_num_cat).fit()
# model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     5229.
# Date:                Mon, 04 Jul 2022   Prob (F-statistic):               0.00
# Time:                        19:44:29   Log-Likelihood:                -4057.6
# No. Observations:               21143   AIC:                             8135.
# Df Residuals:                   21133   BIC:                             8215.
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        12.9663      0.003   4795.336      0.000      12.961      12.972
# bedrooms         -0.0280      0.003    -11.080      0.000      -0.033      -0.023
# bathrooms         0.0388      0.003     11.304      0.000       0.032       0.046
# floors            0.0260      0.003      9.532      0.000       0.021       0.031
# sqft_lot          0.0205      0.002      9.704      0.000       0.016       0.025
# sqft_basement     0.0003   6.17e-06     45.583      0.000       0.000       0.000
# sqft_above        0.2178      0.004     53.273      0.000       0.210       0.226
# lat               0.2077      0.002    100.503      0.000       0.204       0.212
# long             -0.0587      0.002    -25.706      0.000      -0.063      -0.054
# sqft_living15     0.1302      0.003     40.116      0.000       0.124       0.137
# ==============================================================================
# Omnibus:                      302.763   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              556.908
# Skew:                           0.060   Prob(JB):                    1.17e-121
# Kurtosis:                       3.786   Cond. No.                     1.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# yr_built[T.1997]                    0.0999      0.063      1.579      0.114      -0.024       0.224
# yr_built[T.1998]                    0.0905      0.061      1.492      0.136      -0.028       0.209
# yr_built[T.1999]                    0.1388      0.060      2.320      0.020       0.022       0.256
# yr_built[T.2000]                    0.2175      0.061      3.539      0.000       0.097       0.338
# yr_built[T.2001]                    0.2662      0.059      4.530      0.000       0.151       0.381
# yr_built[T.2002]                    0.0640      0.061      1.043      0.297      -0.056       0.184
# yr_built[T.2003]                    0.0653      0.057      1.146      0.252      -0.046       0.177
# yr_built[T.2004]                    0.1192      0.057      2.094      0.036       0.008       0.231
# yr_built[T.2005]                    0.1006      0.057      1.771      0.077      -0.011       0.212
# yr_built[T.2006]                    0.1597      0.057      2.815      0.005       0.049       0.271
# yr_built[T.2007]                    0.1302      0.057      2.280      0.023       0.018       0.242
# yr_built[T.2008]                    0.1503      0.058      2.604      0.009       0.037       0.263
# yr_built[T.2009]                   -0.0140      0.061     -0.230      0.818      -0.134       0.106
# yr_built[T.2010]                    0.0550      0.066      0.837      0.403      -0.074       0.184
# yr_built[T.2011]                    0.0525      0.067      0.783      0.434      -0.079       0.184
# yr_built[T.2012]                    0.0365      0.064      0.572      0.567      -0.089       0.162
# yr_built[T.2013]                    0.2355      0.062      3.792      0.000       0.114       0.357
# yr_built[T.2014]                    0.2830      0.056      5.063      0.000       0.173       0.393
# yr_built[T.2015]                    0.3795      0.094      4.038      0.000       0.195       0.564
# view_unviewed[T.1]                  3.0615      0.015    210.452      0.000       3.033       3.090
# view_viewed[T.1]                    3.6526      0.015    237.553      0.000       3.622       3.683
# yr_renovated_not_renovated[T.1]     3.2089      0.016    204.858      0.000       3.178       3.240
# yr_renovated_renovated[T.1]         3.5052      0.017    201.348      0.000       3.471       3.539
# ==============================================================================
# Omnibus:                      456.539   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              527.133
# Skew:                           0.318   Prob(JB):                    3.42e-115
# Kurtosis:                       3.441   Cond. No.                     2.99e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.89e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # Linear regression using sklearn

# %%
# sample target and independent variable 
# using sklearn.model_selection.train_test_split
X = df_num_cat.drop(['price'],axis = 1)
y = df_num_cat['price']

# %%
# import library
from sklearn.linear_model import LinearRegression

# Creating a linear regressor
linearegression = LinearRegression()

# Training the model

linearegression.fit(X, y)
# Out:
# LinearRegression()

# %%
# y intercept value
linearegression.intercept_
# Out:
# 18.551900744330744

# %%
# coefficients
linearegression.coef_
# Out:
# array([-0.02900752,  0.07435654,  0.04614574,  0.02059053,  0.00022736,
#         0.20362568,  0.19998919, -0.02655559,  0.12321556, -0.00980128,
#        -0.00464634, -0.00274915, -0.09987716,  0.09987716, -0.03989586,
#         0.03989586])

# %%
# checking the pvalues associated with coefficients 
model.pvalues
# Out:
# Intercept       0.00000
# month[T.2]      0.08101
# month[T.3]      0.00000
# month[T.4]      0.00000
# month[T.5]      0.01270
#                   ...
# sqft_basement   0.00000
# sqft_above      0.00000
# lat             0.00000
# long            0.00000
# sqft_living15   0.00000
# Length: 140, dtype: float64

# %% [markdown]
# # Model training

# %% [markdown]
# # Perfoming train-test split

# %%
# Splitting of data in train and test
from sklearn.model_selection import train_test_split

# using 30% of the total data for testing
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.3 , random_state = 42)

# %%
# inspecting X_train
X_train
# Out:
#        bedrooms  bathrooms   floors  sqft_lot  sqft_basement  sqft_above  \
# 20403  -0.40280    0.49955  2.79353  -0.33454        0.00000    -0.07130
# 4107   -0.40280    0.49955 -0.91533   9.04159     1150.00000     0.44776
# 14946   0.67838    1.80074  0.93910  -0.15871     1000.00000     0.85819
# 13990  -0.40280   -1.45222  0.01188  -0.05239        0.00000    -0.61451
# 20767   0.67838    0.49955  0.93910  -0.19139        0.00000     1.15997
# ...         ...        ...      ...       ...            ...         ...
# 11519   0.67838    0.49955  0.93910  -0.03521        0.00000     1.89632
# 12213   1.75956    1.47544  2.79353  -0.24963     1090.00000     1.15997
# 5491   -1.48398   -0.47634 -0.91533  -0.25934      880.00000    -1.09737
# 876    -0.40280   -0.15104 -0.91533  -0.08520      500.00000    -0.45759
# 16139  -1.48398   -1.45222 -0.91533  -0.24769      220.00000    -0.97665
#
#            lat     long  sqft_living15  sqft_lot15 month yr_built  \
# 20403  0.66906 -0.98241       -0.95858    -0.42323     7     2011
# 4107  -1.03595  1.97640        0.51443     6.48935     4     1919
# 14946  0.00740  0.62502        0.52901    -0.09087     6     1994
# 13990 -1.72287 -1.31670       -0.55022     0.24763     8     1942
# 20767  1.24413  1.76303        1.11238    -0.20387     8     2011
# ...        ...      ...            ...         ...   ...      ...
# 11519  0.55577  1.22248        1.44782    -0.07817    11     1987
# 12213  0.23541 -0.54143        0.10607    -0.29220     6     2008
# 5491   0.64741 -0.89706       -0.95858    -0.31502     6     1930
# 876    1.26505  0.11292        0.07690    -0.14682    11     1978
# 16139 -0.23576 -0.93973       -1.38153    -0.28926     6     1943
#
#       view_unviewed view_viewed yr_renovated_not_renovated  \
# 20403             1           0                          1
# 4107              1           0                          0
# 14946             1           0                          1
# 13990             1           0                          1
# 20767             1           0                          1
# ...             ...         ...                        ...
# 11519             1           0                          1
# 12213             0           1                          1
# 5491              1           0                          1
# 876               1           0                          1
# 16139             1           0                          1
#
#       yr_renovated_renovated
# 20403                      0
# 4107                       1
# 14946                      0
# 13990                      0
# 20767                      0
# ...                      ...
# 11519                      0
# 12213                      0
# 5491                       0
# 876                        0
# 16139                      0
#
# [14800 rows x 16 columns]

# %%
# checking the datatypes in X_train
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14800 entries, 20403 to 16139
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   bedrooms                    14800 non-null  float64
#  1   bathrooms                   14800 non-null  float64
#  2   floors                      14800 non-null  float64
#  3   sqft_lot                    14800 non-null  float64
#  4   sqft_basement               14800 non-null  float64
#  5   sqft_above                  14800 non-null  float64
#  6   lat                         14800 non-null  float64
#  7   long                        14800 non-null  float64
#  8   sqft_living15               14800 non-null  float64
#  9   sqft_lot15                  14800 non-null  float64
#  10  month                       14800 non-null  category
#  11  yr_built                    14800 non-null  category
#  12  view_unviewed               14800 non-null  category
#  13  view_viewed                 14800 non-null  category
#  14  yr_renovated_not_renovated  14800 non-null  category
#  15  yr_renovated_renovated      14800 non-null  category
# dtypes: category(6), float64(10)
# memory usage: 1.3 MB

# %%
# Checks if there are any null values
X_train.isna().sum()
# Out:
# bedrooms                      0
# bathrooms                     0
# floors                        0
# sqft_lot                      0
# sqft_basement                 0
# sqft_above                    0
# lat                           0
# long                          0
# sqft_living15                 0
# sqft_lot15                    0
# month                         0
# yr_built                      0
# view_unviewed                 0
# view_viewed                   0
# yr_renovated_not_renovated    0
# yr_renovated_renovated        0
# dtype: int64

# %%
# Inspecting y_train
y_train
# Out:
# 20403   13.34551
# 4107    13.38465
# 14946   13.59112
# 13990   12.54219
# 20767   12.97154
#           ...
# 11519   13.54763
# 12213   14.19395
# 5491    13.36922
# 876     12.87390
# 16139   12.40901
# Name: price, Length: 14800, dtype: float64

# %%
# inspecting data in X_test 
X_test
# Out:
#        bedrooms  bathrooms   floors  sqft_lot  sqft_basement  sqft_above  \
# 12677  -0.40280    1.80074 -0.91533  -0.19503     1500.00000    -0.26445
# 11076  -0.40280   -0.80163 -0.91533  -0.23993      400.00000    -0.91630
# 9005    0.67838    0.49955  0.93910  -0.15291        0.00000     1.43761
# 18455  -1.48398    0.49955  0.93910  -0.30086        0.00000    -0.66280
# 9155   -0.40280   -1.45222 -0.91533  -0.16057        0.00000    -0.95251
# ...         ...        ...      ...       ...            ...         ...
# 8814   -1.48398   -0.15104  0.93910  -0.26674        0.00000    -0.61451
# 12722   0.67838    0.17426  0.93910  -0.06278        0.00000     0.27876
# 7778   -1.48398   -1.45222 -0.91533  -0.24478        0.00000    -1.07322
# 4161    0.67838    0.49955  0.93910   0.14033     1060.00000     0.39948
# 17655  -0.40280    0.17426  0.93910  -0.22653        0.00000     0.06148
#
#            lat     long  sqft_living15  sqft_lot15 month yr_built  \
# 12677  1.06302 -0.44186        0.52901    -0.25242     2     1928
# 11076 -1.41332  0.85262       -1.16276    -0.27748    12     1977
# 9005  -1.31519  1.30783        1.44782    -0.22161     9     2003
# 18455 -1.70771 -0.77615       -0.81274    -0.33604     6     1986
# 9155  -1.83759 -1.11043       -1.41069    -0.15712     3     1963
# ...        ...      ...            ...         ...   ...      ...
# 8814  -0.07341 -1.27402       -0.75440    -0.26644     9     1918
# 12722 -0.14412  0.27651       -0.27312     0.01605     1     1966
# 7778  -2.59377  1.55676       -1.22110    -0.28484     2     1930
# 4161   1.13518 -0.19292        1.03946     0.05341    11     1967
# 17655  1.03849  0.19116       -0.46272    -0.37826     5     2003
#
#       view_unviewed view_viewed yr_renovated_not_renovated  \
# 12677             0           1                          0
# 11076             1           0                          1
# 9005              1           0                          1
# 18455             1           0                          1
# 9155              1           0                          1
# ...             ...         ...                        ...
# 8814              1           0                          1
# 12722             1           0                          1
# 7778              1           0                          0
# 4161              1           0                          1
# 17655             1           0                          1
#
#       yr_renovated_renovated
# 12677                      1
# 11076                      0
# 9005                       0
# 18455                      0
# 9155                       0
# ...                      ...
# 8814                       0
# 12722                      0
# 7778                       1
# 4161                       0
# 17655                      0
#
# [6343 rows x 16 columns]

# %%
# checking the datatypes in X_test
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6343 entries, 12677 to 17655
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   bedrooms                    6343 non-null   float64
#  1   bathrooms                   6343 non-null   float64
#  2   floors                      6343 non-null   float64
#  3   sqft_lot                    6343 non-null   float64
#  4   sqft_basement               6343 non-null   float64
#  5   sqft_above                  6343 non-null   float64
#  6   lat                         6343 non-null   float64
#  7   long                        6343 non-null   float64
#  8   sqft_living15               6343 non-null   float64
#  9   sqft_lot15                  6343 non-null   float64
#  10  month                       6343 non-null   category
#  11  yr_built                    6343 non-null   category
#  12  view_unviewed               6343 non-null   category
#  13  view_viewed                 6343 non-null   category
#  14  yr_renovated_not_renovated  6343 non-null   category
#  15  yr_renovated_renovated      6343 non-null   category
# dtypes: category(6), float64(10)
# memory usage: 588.1 KB

# %%
# checking what y_test contains
y_test
# Out:
# 12677   13.65299
# 11076   12.18075
# 9005    12.85448
# 18455   12.06968
# 9155    12.18587
#           ...
# 8814    12.95984
# 12722   12.83468
# 7778    12.25486
# 4161    13.16734
# 17655   13.04979
# Name: price, Length: 6343, dtype: float64

# %% [markdown]
# # Prediction

# %%
# importing required library
from sklearn.linear_model import LinearRegression
linearegression = LinearRegression ()

# %%
#fitting the model
linearegression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# inspecting y_train
y_train
# Out:
# 20403   13.34551
# 4107    13.38465
# 14946   13.59112
# 13990   12.54219
# 20767   12.97154
#           ...
# 11519   13.54763
# 12213   14.19395
# 5491    13.36922
# 876     12.87390
# 16139   12.40901
# Name: price, Length: 14800, dtype: float64

# %%
# assigning X_test prediction to a variable
y_pred1 = linearegression.predict(X_test)
y_pred1
# Out:
# array([14.03975746, 12.28065639, 13.09580221, ..., 12.13195376,
#        13.69837764, 13.10679829])

# %%
# inspecting y_test
y_test
# Out:
# 12677   13.65299
# 11076   12.18075
# 9005    12.85448
# 18455   12.06968
# 9155    12.18587
#           ...
# 8814    12.95984
# 12722   12.83468
# 7778    12.25486
# 4161    13.16734
# 17655   13.04979
# Name: price, Length: 6343, dtype: float64

# %%
# inspecting X_test
X_test
# Out:
#        bedrooms  bathrooms   floors  sqft_lot  sqft_basement  sqft_above  \
# 12677  -0.40280    1.80074 -0.91533  -0.19503     1500.00000    -0.26445
# 11076  -0.40280   -0.80163 -0.91533  -0.23993      400.00000    -0.91630
# 9005    0.67838    0.49955  0.93910  -0.15291        0.00000     1.43761
# 18455  -1.48398    0.49955  0.93910  -0.30086        0.00000    -0.66280
# 9155   -0.40280   -1.45222 -0.91533  -0.16057        0.00000    -0.95251
# ...         ...        ...      ...       ...            ...         ...
# 8814   -1.48398   -0.15104  0.93910  -0.26674        0.00000    -0.61451
# 12722   0.67838    0.17426  0.93910  -0.06278        0.00000     0.27876
# 7778   -1.48398   -1.45222 -0.91533  -0.24478        0.00000    -1.07322
# 4161    0.67838    0.49955  0.93910   0.14033     1060.00000     0.39948
# 17655  -0.40280    0.17426  0.93910  -0.22653        0.00000     0.06148
#
#            lat     long  sqft_living15  sqft_lot15 month yr_built  \
# 12677  1.06302 -0.44186        0.52901    -0.25242     2     1928
# 11076 -1.41332  0.85262       -1.16276    -0.27748    12     1977
# 9005  -1.31519  1.30783        1.44782    -0.22161     9     2003
# 18455 -1.70771 -0.77615       -0.81274    -0.33604     6     1986
# 9155  -1.83759 -1.11043       -1.41069    -0.15712     3     1963
# ...        ...      ...            ...         ...   ...      ...
# 8814  -0.07341 -1.27402       -0.75440    -0.26644     9     1918
# 12722 -0.14412  0.27651       -0.27312     0.01605     1     1966
# 7778  -2.59377  1.55676       -1.22110    -0.28484     2     1930
# 4161   1.13518 -0.19292        1.03946     0.05341    11     1967
# 17655  1.03849  0.19116       -0.46272    -0.37826     5     2003
#
#       view_unviewed view_viewed yr_renovated_not_renovated  \
# 12677             0           1                          0
# 11076             1           0                          1
# 9005              1           0                          1
# 18455             1           0                          1
# 9155              1           0                          1
# ...             ...         ...                        ...
# 8814              1           0                          1
# 12722             1           0                          1
# 7778              1           0                          0
# 4161              1           0                          1
# 17655             1           0                          1
#
#       yr_renovated_renovated
# 12677                      1
# 11076                      0
# 9005                       0
# 18455                      0
# 9155                       0
# ...                      ...
# 8814                       0
# 12722                      0
# 7778                       1
# 4161                       0
# 17655                      0
#
# [6343 rows x 16 columns]

# %%
# model for both numerical and categorical data

# %%
x_cols = ['bedrooms','bathrooms','floors','sqft_lot','sqft_basement','sqft_above','lat','long','sqft_living15','month','yr_built','view_unviewed','view_viewed','yr_renovated_not_renovated','yr_renovated_renovated']
predictors = '+'.join(x_cols)
formula = 'price' + '~' + predictors
model = smf.ols(formula=formula, data=df_num_cat).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.726
# Method:                 Least Squares   F-statistic:                     410.7
# Date:                Mon, 04 Jul 2022   Prob (F-statistic):               0.00
# Time:                        23:01:26   Log-Likelihood:                -2673.3
# No. Observations:               21143   AIC:                             5623.
# Df Residuals:                   21005   BIC:                             6721.
# Df Model:                         137
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           6.6436      0.016    417.187      0.000       6.612       6.675
# month[T.2]                          0.0208      0.012      1.745      0.081      -0.003       0.044
# month[T.3]                          0.0626      0.011      5.674      0.000       0.041       0.084
# month[T.4]                          0.0816      0.011      7.605      0.000       0.061       0.103
# month[T.5]                          0.0264      0.011      2.492      0.013       0.006       0.047
# month[T.6]                          0.0246      0.011      2.286      0.022       0.004       0.046
# month[T.7]                          0.0167      0.011      1.549      0.121      -0.004       0.038
# month[T.8]                          0.0134      0.011      1.220      0.223      -0.008       0.035
# month[T.9]                          0.0073      0.011      0.654      0.513      -0.015       0.029
# month[T.10]                         0.0068      0.011      0.620      0.535      -0.015       0.028
# month[T.11]                         0.0073      0.012      0.625      0.532      -0.016       0.030
# month[T.12]                        -0.0025      0.012     -0.212      0.832      -0.025       0.020
# yr_built[T.1901]                    0.0347      0.060      0.578      0.564      -0.083       0.153
# yr_built[T.1902]                    0.0324      0.061      0.531      0.596      -0.087       0.152
# yr_built[T.1903]                   -0.0666      0.051     -1.298      0.194      -0.167       0.034
# yr_built[T.1904]                    0.0326      0.051      0.636      0.525      -0.068       0.133
# yr_built[T.1905]                    0.0672      0.044      1.512      0.131      -0.020       0.154
# yr_built[T.1906]                    0.0723      0.042      1.724      0.085      -0.010       0.155
# view_viewed[T.1]                    3.4254      0.009    376.847      0.000       3.408       3.443
# yr_renovated_not_renovated[T.1]     3.2786      0.009    357.843      0.000       3.261       3.297
# yr_renovated_renovated[T.1]         3.3650      0.010    331.191      0.000       3.345       3.385
# bedrooms                           -0.0250      0.002    -10.083      0.000      -0.030      -0.020
# bathrooms                           0.0689      0.004     19.486      0.000       0.062       0.076
# floors                              0.0269      0.003      8.794      0.000       0.021       0.033
# sqft_lot                            0.0160      0.002      7.986      0.000       0.012       0.020
# sqft_basement                       0.0002      6e-06     37.657      0.000       0.000       0.000
# sqft_above                          0.2031      0.004     52.190      0.000       0.195       0.211
# lat                                 0.1990      0.002     98.798      0.000       0.195       0.203
# long                               -0.0244      0.002    -10.405      0.000      -0.029      -0.020
# sqft_living15                       0.1239      0.003     39.559      0.000       0.118       0.130
# ==============================================================================
# Omnibus:                      558.495   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1332.404
# Skew:                          -0.079   Prob(JB):                    4.70e-290
# Kurtosis:                       4.220   Cond. No.                     8.48e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.26e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # Calculating error terms

# %%
# importing the necessary library
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test, y_pred1)
r_squared = r2_score(y_test, y_pred1)

# %%
# output the mean_squared_error and r_squared_value
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 0.07784943562810645
# r_square_value : 0.7186941771163959

# %%
'''
Our r_squared for both numerical and categorical data from the model is 0.728
'''
# Out:
# '\nOur r_squared for both numerical and categorical data from the model is 0.728\n'

# %%
import sklearn.metrics as metrics

print('R^2:', metrics.r2_score(y_train,y_pred1))
print('Adjusted R^2:', 1-(1-metrics.r2_score(y_train, y_pred1))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:', metrics.mean_absolute_error(y_train, y_pred1))
print('MSE:', metrics.mean_squared_error(y_train, y_pred1))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25364/63591955.py in <module>
#       1 import sklearn.metrics as metrics
#       2
# ----> 3 print('R^2:', metrics.r2_score(y_train,y_pred1))
#       4 print('Adjusted R^2:', 1-(1-metrics.r2_score(y_train, y_pred1))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
#       5 print('MAE:', metrics.mean_absolute_error(y_train, y_pred1))
#
# ~\anaconda3\An4\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\An4\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     674     -3.0
#     675     """
# --> 676     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     677         y_true, y_pred, multioutput)
#     678     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\An4\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      86         the dtype argument passed to check_array.
#      87     """
# ---> 88     check_consistent_length(y_true, y_pred)
#      89     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      90     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\An4\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     317     uniques = np.unique(lengths)
#     318     if len(uniques) > 1:
# --> 319         raise ValueError("Found input variables with inconsistent numbers of"
#     320                          " samples: %r" % [int(l) for l in lengths])
#     321
#
# ValueError: Found input variables with inconsistent numbers of samples: [14800, 6343]

# %%
y_train.shape
# Out:
# (14800,)

# %%
y_pred1.shape
# Out:
# (6343,)

# %%
# scatterplot to show the distribution of actual prices vs predicted prices

plt.figure(figsize = (10,6))
sns.scatterplot(x= X_train ,y = y_pred1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25364/2454714170.py in <module>
#       2
#       3 plt.figure(figsize = (10,6))
# ----> 4 sns.scatterplot(x= X_train ,y = y_pred1)
#
# ~\anaconda3\An4\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\An4\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#
# ~\anaconda3\An4\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# ~\anaconda3\An4\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\An4\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# ~\anaconda3\An4\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     925         # Construct a tidy plot DataFrame. This will convert a number of
#     926         # types automatically, aligning on index in case of pandas objects
# --> 927         plot_data = pd.DataFrame(plot_data)
#     928
#     929         # Reduce the variables dictionary to fields with valid data
#
# ~\anaconda3\An4\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\An4\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\An4\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     122
#     123         # don't force copy because getting jammed in an ndarray anyway
# --> 124         arrays = _homogenize(arrays, index, dtype)
#     125
#     126     else:
#
# ~\anaconda3\An4\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     587                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     588
# --> 589             val = sanitize_array(
#     590                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     591             )
#
# ~\anaconda3\An4\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     574                 subarr = maybe_infer_to_datetimelike(subarr)
#     575
# --> 576     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     577
#     578     if isinstance(subarr, np.ndarray):
#
# ~\anaconda3\An4\lib\site-packages\pandas\core\construction.py in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     625             if allow_2d:
#     626                 return result
# --> 627             raise ValueError("Data must be 1-dimensional")
#     628         if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     629             # i.e. PandasDtype("O")
#
# ValueError: Data must be 1-dimensional

# %%
# checking for P-value using statsmodel

import statsmodels.api as sm
X_train_sm = X_train
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(y_train,X_train_sm).fit()

# print the coefficients
lm_1.params

# %%
# summary of the model
print(lm_1.summary())

# %%
'''
The difference between r_squared and adjusted r_squared is not that much, thus negligible
'''

# %% [markdown]
# # final model

# %%
# creating a new dataframe "df_final" that has columns that will be retained
# dropping columns
final_model = df_num_cat.drop(["sqft_lot","long","sqft_lot15","yr_built","month","yr_renovated_renovated","yr_renovated_not_renovated","view_unviewed","view_viewed"], axis=1)

# %%
# final model
final_cols = final_model.drop(['price'],axis=1) #let's see what our final model looks like
formula = 'price ~ ' + ' + '.join(final_cols) 
model = smf.ols(formula=formula, data = final_model) 
res = model.fit()
# getting the model summary
res.summary()

# %%
# final observation

# Most predictors have a positive relationship with price
# Sqft-above had the highest slope followed by sqft_living15.
# The sqft_above(square footage of house apart from basement) seems to be the one that matters most when it came to price. 
# A slight increase in sqft_above space there is a significant increase in price.
# Sqft_living15 seemed to also be a major aspect of prediction as it has a strong positive relationship with price as we could see in the slope of the jointplot
# There was no negative relationship betweeen predictors and target variable
# The final model hads predictors with a p_value of less than 0.05 and an r_squared value of 0.7
# final prediction variables include sqft_above,sqft_living15,bathrooms,sqft_basement,bedrooms,floors,view
